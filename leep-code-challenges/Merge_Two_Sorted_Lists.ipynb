# %% [markdown]
# ## Merge Two Sorted Lists
#
#
# You are given the heads of two sorted linked lists list1 and list2.
#
# Merge the two lists into one sorted list. The list should be made by splicing together the nodes of the first two lists.
#
# Return the head of the merged linked list.
#
#
#
# Example 1:
# ![image.png](attachment:image.png)
#
# * Input: list1 = [1,2,4], list2 = [1,3,4]
# * Output: [1,1,2,3,4,4]
#
#
# Example 2:
#
# * Input: list1 = [], list2 = []
# * Output: []
#
#
# Example 3:
#
# * Input: list1 = [], list2 = [0]
# * Output: [0]
#
#
# Constraints:
#
# The number of nodes in both lists is in the range [0, 50].
#
# -100 <= Node.val <= 100
#
# Both list1 and list2 are sorted in non-decreasing order.

# %%
#Definition for singly-linked list.

class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# %% [markdown]
# > iterative method

# %%
class Solution(object):
    def mergeTwoLists(self, list1, list2):
        """
        :type list1: Optional[ListNode]
        :type list2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """

        # """
        # result_node
        # left_pointer \ right_pointer
        # while node1 & node2 none:
        #     if node1 none -> left_pointer = -inf
        #     if node2 none -> right_pointer = -inf
 
        #     left_pointer = list1.val
        #     right_pointer = list2.val

        #     if( left_pointer >= right_pointer ):
        #         temp_node = left_pointer
        #         list1 = list1.next
        #     else:
        #         temp_node = right_pointer
        #         list2 = list2.next

        # return result_node
        # """

        result_node = ListNode()
        head_ref = result_node
        #define two pointers
        list1_pointer , list2_pointer = None , None
        while ( (list1 is not None) | (list2 is not None) ):
            list1_pointer = list1.val if list1 is not None else float('inf')
            list2_pointer = list2.val if list2 is not None else float('inf')

            if( list1_pointer <= list2_pointer ):
                temp_node = ListNode(list1_pointer)
                head_ref.next = temp_node
                head_ref = temp_node
                #update the pointer
                list1 = list1.next
            else:
                temp_node = ListNode(list2_pointer)
                head_ref.next = temp_node
                head_ref = temp_node
                list2= list2.next

        return result_node.next

# %% [markdown]
# > recursive method

# %%
class Solution(object):
    def mergeTwoLists(self, list1, list2):
        """
        :type list1: Optional[ListNode]
        :type list2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """

        if ( not(list1 and list2) ):
            return list1 if list1 is not None else list2

        if ( list1.val <= list2.val ):
            # if( list1.next is None ):
            #     list1.next = list2
            #     return list1
            # else:
            list1.next = self.mergeTwoLists(list1.next , list2)
            return list1
        else:
            # if( list2.next is None ):
            #     list2.next = list1
            #     return list2
            #else:
            list2.next = self.mergeTwoLists(list1 , list2.next)
            return list2
